# %%
import pandas as pd

# %%
df=pd.read_csv('RECLAMEAQUI_HAPVIDA.csv')

# %%
df.head(10)
# Out:
#           ID                                               TEMA  \
# 0  149490335                              TEMPO DE ATENDIMENTO
# 1  149499817                         Hapvida não tem nutrólogo
# 2  149498293               Descaso de tratamento de Hemodiálise
# 3  149495455    DESORGANIZAÇÃO E FALTA DE RESOLUÇÃO DE PROBLEMA
# 4  149495285                         Liberação de Procedimento
# 5  149494731                                 FALTA DE ESTRUTURA
# 6  149493275  Hapvida cobrando coparticipação de pré natal, ...
# 7  149500357                                         Revoltada
# 8  149491487                                  Aumento do Plano!
# 9  149484689                        Atraso na entrega do exame
#
#             LOCAL       TEMPO  \
# 0     Recife - PE  2022-01-09
# 1   Salvador - BA  2022-01-09
# 2     Olinda - PE  2022-01-09
# 3    Goiânia - GO  2022-01-09
# 4  Fortaleza - CE  2022-01-09
# 5   Salvador - BA  2022-01-09
# 6  São Paulo - SP  2022-01-09
# 7   Salvador - BA  2022-01-09
# 8   Salvador - BA  2022-01-09
# 9   Salvador - BA  2022-01-09
#
#                                            CATEGORIA          STATUS  \
# 0  Demora na execução<->Plano<->Planos de Saúde<-...  Não respondida
# 1  Planos de saúde<->Qualidade do serviço prestad...  Não respondida
# 2  Demora para autorização de consultas, exames e...      Respondida
# 3  Demora na execução<->Planos de saúde<->Planos ...  Não respondida
# 4  Planos de saúde<->Planos de Saúde<->Hapvida Sa...      Respondida
# 5  Banheiro<->Problemas de infraestrutura<->Não e...      Respondida
# 6  Planos de saúde<->Cobrança indevida<->Planos d...  Não respondida
# 7  Plano<->Planos de Saúde<->Qualidade do serviço...       Resolvido
# 8  Planos de saúde<->Reajuste abusivo<->Planos de...  Não respondida
# 9  Exames Lab e imagens<->Atraso na entrega dos r...      Respondida
#
#                                            DESCRICAO  \
# 0  Acabei de sair de uma urgência por causa de at...
# 1  O Hapvida diz que fornece o serviço de nutrólo...
# 2  Meu irmão Wagner Santiago, estava internado de...
# 3  Agendei pelo chat um procedimento onde fui bem...
# 4  Paguei fatura do plano em atraso e tal atraso ...
# 5  MEU ESPOSO TINHA ENDOSCOPIA MARCADA HOJE (01/0...
# 6  Eu irei passar toda a minha gestação praticame...
# 7  Fiquei a mais de 1 mês aguardando a consulta p...
# 8  Boa tarde, site tem várias promoções para clie...
# 9  Residimos na cidade de Feira de Santana e meu ...
#
#                                                  URL   ANO  MES  DIA  \
# 0  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 1  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 2  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 3  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 4  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 5  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 6  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 7  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 8  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 9  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
#
#    DIA_DO_ANO  SEMANA_DO_ANO  DIA_DA_SEMANA  TRIMETRES  CASOS
# 0           9              1              6          1     66
# 1           9              1              6          1     66
# 2           9              1              6          1     66
# 3           9              1              6          1     66
# 4           9              1              6          1     66
# 5           9              1              6          1     66
# 6           9              1              6          1     66
# 7           9              1              6          1     66
# 8           9              1              6          1     66
# 9           9              1              6          1     66

# %%
df['TEMPO']=pd.to_datetime(df['TEMPO'])

# %%
df.groupby('TEMPO').nunique()['ID'].plot()
# Out:
# <Axes: xlabel='TEMPO'>

# %%
df.STATUS.value_counts()
# Out:
# STATUS
# Não respondida    639
# Respondida        271
# Resolvido          67
# Em réplica         36
# Não resolvido       3
# Name: count, dtype: int64

# %%
df['LOCAL'].iloc[0]
# Out:
# 'Recife - PE'

# %%
df['LOCAL'].iloc[0][-2:]
# Out:
# 'PE'

# %%
df['LOCAL'].iloc[0].split('-')[1].strip()
# Out:
# 'PE'

# %%
estado_lista=[]
for i in range(len(df)):
    estado_lista.append(df['LOCAL'].iloc[i].split('-',2)[1].strip())

# %%
estado_lista
# Out:
# ['PE',
#  'BA',
#  'PE',
#  'GO',
#  'CE',
#  'BA',
#  'SP',
#  'BA',
#  'BA',
#  'BA',
#  'PE',
#  'MA',
#  'GO',
#  'PA',
#  'PE',
#  'BA',
#  'SP',
#  'PE',
#  'AL',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'BA',
#  'PE',
#  'BA',
#  'GO',
#  'CE',
#  'PE',
#  'GO',
#  'BA',
#  'RN',
#  'CE',
#  'SP',
#  'RN',
#  'CE',
#  'PB',
#  'SP',
#  'AL',
#  'BA',
#  'BA',
#  'PB',
#  'RN',
#  'SP',
#  '',
#  'GO',
#  'SP',
#  'MS',
#  'MS',
#  'MS',
#  'SP',
#  'SP',
#  'AL',
#  'PE',
#  'BA',
#  'ES',
#  'BA',
#  'MS',
#  'MA',
#  'BA',
#  'SP',
#  'SP',
#  'SP',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'BA',
#  'GO',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'GO',
#  'PE',
#  'SP',
#  'CE',
#  'PB',
#  'PB',
#  'RN',
#  'PE',
#  'AM',
#  'CE',
#  'CE',
#  'MT',
#  'CE',
#  'PE',
#  'AL',
#  'PE',
#  'CE',
#  'RN',
#  'BA',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'CE',
#  'SP',
#  'PA',
#  'PE',
#  'RN',
#  'BA',
#  'MS',
#  'RN',
#  'PA',
#  'BA',
#  'AL',
#  'SP',
#  'SP',
#  'CE',
#  'PE',
#  'GO',
#  'SP',
#  'GO',
#  'SP',
#  'CE',
#  'CE',
#  'AL',
#  'BA',
#  'GO',
#  'CE',
#  'CE',
#  'SE',
#  'PE',
#  'PE',
#  'CE',
#  'SP',
#  'PE',
#  'RN',
#  'BA',
#  'SP',
#  'PB',
#  'BA',
#  'PE',
#  'CE',
#  'CE',
#  'GO',
#  'BA',
#  'SP',
#  'GO',
#  'PE',
#  'SE',
#  'AM',
#  'SP',
#  'GO',
#  'CE',
#  'CE',
#  'AM',
#  'MG',
#  'SE',
#  'GO',
#  'BA',
#  'BA',
#  'PE',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'PE',
#  'BA',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'CE',
#  'RN',
#  'BA',
#  'PE',
#  'SP',
#  'PE',
#  'CE',
#  'AL',
#  'PE',
#  'BA',
#  'CE',
#  'BA',
#  'BA',
#  'GO',
#  'GO',
#  'BA',
#  'GO',
#  'SP',
#  'GO',
#  'BA',
#  'BA',
#  'CE',
#  'SP',
#  'SP',
#  'PE',
#  'CE',
#  'CE',
#  'BA',
#  'PE',
#  'PA',
#  'PE',
#  'CE',
#  'SP',
#  'BA',
#  'CE',
#  'PA',
#  'RN',
#  'PE',
#  'RS',
#  'CE',
#  'GO',
#  'PE',
#  'CE',
#  'PA',
#  'PA',
#  'PE',
#  'BA',
#  'CE',
#  'PE',
#  'RR',
#  'BA',
#  'BA',
#  'SP',
#  'SP',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'GO',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'BA',
#  'BA',
#  'PE',
#  'CE',
#  'AM',
#  'PE',
#  'MS',
#  'RJ',
#  'GO',
#  'RN',
#  'PA',
#  'CE',
#  'RN',
#  'CE',
#  'GO',
#  'GO',
#  'PE',
#  'SP',
#  'CE',
#  'SE',
#  'PE',
#  'PE',
#  'PE',
#  'SP',
#  'AM',
#  'SP',
#  'CE',
#  'PB',
#  'MG',
#  'GO',
#  'SP',
#  'MG',
#  'PE',
#  'CE',
#  'SP',
#  'BA',
#  'PA',
#  'GO',
#  'BA',
#  'MT',
#  'PE',
#  'MA',
#  'BA',
#  'SP',
#  'BA',
#  'SP',
#  'RN',
#  'SP',
#  'GO',
#  'MS',
#  'SP',
#  'CE',
#  'CE',
#  'CE',
#  'AM',
#  'RN',
#  'PE',
#  'MG',
#  'BA',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'CE',
#  'PE',
#  'RN',
#  'BA',
#  'PE',
#  'PA',
#  'MS',
#  'PB',
#  'SP',
#  'GO',
#  'SE',
#  'GO',
#  'CE',
#  'PA',
#  'PE',
#  'SP',
#  'SP',
#  'BA',
#  'GO',
#  'BA',
#  'CE',
#  'SP',
#  'PE',
#  'PE',
#  'SP',
#  'CE',
#  'CE',
#  'BA',
#  'PB',
#  'CE',
#  'CE',
#  'CE',
#  'GO',
#  'BA',
#  'GO',
#  'BA',
#  'PE',
#  'BA',
#  'RN',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'MA',
#  'AM',
#  'PB',
#  'MS',
#  'SP',
#  'CE',
#  'AM',
#  'AL',
#  '',
#  'CE',
#  'SP',
#  'SP',
#  'SP',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'GO',
#  'BA',
#  'BA',
#  'BA',
#  'SP',
#  'SP',
#  'PE',
#  'CE',
#  'RJ',
#  'PE',
#  'PE',
#  'BA',
#  'PA',
#  'RN',
#  'CE',
#  'SP',
#  'SP',
#  'CE',
#  'SP',
#  'PE',
#  'CE',
#  'GO',
#  'MA',
#  'RN',
#  'CE',
#  'PE',
#  'SP',
#  'GO',
#  'MS',
#  'PB',
#  'MS',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'PE',
#  'CE',
#  'GO',
#  'AM',
#  'CE',
#  'SP',
#  'BA',
#  'CE',
#  'MS',
#  'BA',
#  'RS',
#  'PE',
#  'PE',
#  'CE',
#  'SP',
#  'CE',
#  'GO',
#  'PE',
#  'CE',
#  'RN',
#  'SP',
#  'SP',
#  'PE',
#  'SP',
#  'PA',
#  'SC',
#  'PE',
#  'BA',
#  'CE',
#  'RN',
#  'MS',
#  'PE',
#  'CE',
#  'BA',
#  'MT',
#  'SP',
#  'RN',
#  'CE',
#  'PE',
#  'PB',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'RN',
#  'PI',
#  'CE',
#  'MS',
#  'PA',
#  'BA',
#  'SP',
#  'CE',
#  'SP',
#  'SP',
#  'SP',
#  'SP',
#  'PE',
#  'PE',
#  'SP',
#  'PE',
#  'CE',
#  'BA',
#  'BA',
#  'CE',
#  'PE',
#  'GO',
#  'BA',
#  'AM',
#  'BA',
#  'PE',
#  'PE',
#  'PE',
#  'SE',
#  'BA',
#  'RN',
#  'CE',
#  'PB',
#  'PE',
#  'PE',
#  'SP',
#  'PE',
#  'ES',
#  'CE',
#  'CE',
#  'CE',
#  'SE',
#  'CE',
#  'CE',
#  'BA',
#  'PA',
#  'CE',
#  'PI',
#  'CE',
#  'PE',
#  'PE',
#  'BA',
#  'PE',
#  'PE',
#  'SE',
#  'GO',
#  'PB',
#  'CE',
#  'ES',
#  'SP',
#  'AL',
#  'AL',
#  'AM',
#  'SP',
#  'CE',
#  'BA',
#  'CE',
#  'CE',
#  'BA',
#  'BA',
#  'BA',
#  'PE',
#  'BA',
#  'PE',
#  'MA',
#  'SP',
#  'BA',
#  'SP',
#  'PA',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'CE',
#  'PE',
#  'PE',
#  'RN',
#  'SP',
#  'PE',
#  'BA',
#  'PE',
#  'SP',
#  'BA',
#  'CE',
#  'AM',
#  'BA',
#  'BA',
#  'SP',
#  'BA',
#  'GO',
#  'RN',
#  'BA',
#  'GO',
#  'CE',
#  'PE',
#  'SP',
#  'RN',
#  'GO',
#  'PE',
#  'BA',
#  'SP',
#  'SP',
#  'TO',
#  'SC',
#  'PE',
#  'AL',
#  'PE',
#  'CE',
#  'BA',
#  'MG',
#  'BA',
#  'PE',
#  'BA',
#  'BA',
#  'AM',
#  'CE',
#  'GO',
#  'PB',
#  'BA',
#  'CE',
#  'PE',
#  'SP',
#  'GO',
#  'SP',
#  'BA',
#  'PE',
#  'GO',
#  'AL',
#  'SP',
#  'BA',
#  'CE',
#  'AM',
#  'PE',
#  'SP',
#  'PE',
#  'SP',
#  'BA',
#  'SP',
#  'PE',
#  'GO',
#  'CE',
#  'SC',
#  'GO',
#  'PE',
#  'BA',
#  'SC',
#  'BA',
#  'BA',
#  'DF',
#  'CE',
#  'GO',
#  'SP',
#  'PE',
#  'RN',
#  'MT',
#  'BA',
#  'PB',
#  'CE',
#  'MA',
#  'CE',
#  'PE',
#  'GO',
#  'PE',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'CE',
#  'BA',
#  'PE',
#  'CE',
#  'PE',
#  'SP',
#  'RN',
#  'GO',
#  'GO',
#  'GO',
#  'CE',
#  'BA',
#  'CE',
#  'SC',
#  'BA',
#  'BA',
#  'RN',
#  'GO',
#  'MA',
#  'PE',
#  'AM',
#  'BA',
#  'SP',
#  'GO',
#  'SP',
#  'PA',
#  'CE',
#  'PE',
#  'PE',
#  'BA',
#  'PE',
#  'CE',
#  'SP',
#  'PE',
#  'RJ',
#  'CE',
#  'BA',
#  'BA',
#  'MG',
#  'PB',
#  'CE',
#  'PE',
#  'PE',
#  'SP',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'PA',
#  'GO',
#  'SP',
#  'MG',
#  'PE',
#  'BA',
#  'PB',
#  'SP',
#  'AM',
#  'AL',
#  'BA',
#  'PE',
#  'PE',
#  'PE',
#  'BA',
#  'BA',
#  'PE',
#  'MA',
#  'BA',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'SC',
#  'SP',
#  'GO',
#  'SP',
#  'MS',
#  'RN',
#  'RN',
#  'BA',
#  'CE',
#  'CE',
#  'SE',
#  'GO',
#  'GO',
#  'PE',
#  'GO',
#  'CE',
#  'BA',
#  'SP',
#  'BA',
#  'CE',
#  'RN',
#  'GO',
#  'CE',
#  'GO',
#  'CE',
#  'SP',
#  'BA',
#  'AL',
#  'RN',
#  'PB',
#  'RN',
#  'DF',
#  'PE',
#  'CE',
#  'RN',
#  'CE',
#  'GO',
#  'CE',
#  'CE',
#  'GO',
#  'PB',
#  'PA',
#  'CE',
#  'PE',
#  'SP',
#  'PE',
#  'PE',
#  'PE',
#  'AM',
#  'PE',
#  'MG',
#  'GO',
#  'GO',
#  'GO',
#  'MS',
#  'RN',
#  'DF',
#  'SP',
#  'CE',
#  'BA',
#  'AL',
#  'SP',
#  'PB',
#  'AM',
#  'CE',
#  'CE',
#  'PA',
#  'GO',
#  'CE',
#  'SP',
#  'CE',
#  'SE',
#  'AM',
#  'PE',
#  'SP',
#  'CE',
#  'GO',
#  'CE',
#  'SP',
#  'BA',
#  'PE',
#  'GO',
#  'CE',
#  'SP',
#  'SP',
#  'BA',
#  'BA',
#  'CE',
#  'PE',
#  'PE',
#  'PE',
#  'PE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'PE',
#  'PE',
#  'SP',
#  'CE',
#  'CE',
#  'SP',
#  'PA',
#  'CE',
#  'SP',
#  'PE',
#  'SE',
#  'CE',
#  'GO',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'PI',
#  'SP',
#  'RN',
#  'AL',
#  'RN',
#  'BA',
#  'GO',
#  'CE',
#  'PI',
#  'CE',
#  'RN',
#  'AM',
#  'PB',
#  'PE',
#  'RN',
#  'MS',
#  'PE',
#  'AL',
#  'MS',
#  'MS',
#  'GO',
#  'BA',
#  'SP',
#  'CE',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'BA',
#  'RN',
#  'CE',
#  'BA',
#  'PE',
#  'AM',
#  'MT',
#  'SP',
#  'BA',
#  'CE',
#  'SP',
#  'CE',
#  'GO',
#  'GO',
#  'CE',
#  'PE',
#  'RN',
#  'PE',
#  'PE',
#  'DF',
#  'GO',
#  'CE',
#  'SP',
#  'CE',
#  'BA',
#  'BA',
#  'GO',
#  'PE',
#  'CE',
#  'SP',
#  'BA',
#  'BA',
#  'AL',
#  'BA',
#  'BA',
#  'SP',
#  'GO',
#  'GO',
#  'CE',
#  'MA',
#  'SP',
#  'GO',
#  'BA',
#  'RN',
#  'RN',
#  'SP',
#  'SP',
#  'CE',
#  'RN',
#  'RN',
#  'PE',
#  'GO',
#  'CE',
#  'RN',
#  'PA',
#  'MS',
#  'RN',
#  'SP',
#  'RN',
#  'BA',
#  'SP',
#  'PI',
#  'RN',
#  'CE',
#  'GO',
#  'CE',
#  'SP',
#  'BA',
#  'CE',
#  'SE',
#  'CE',
#  'PE',
#  'RN',
#  'PB',
#  'GO',
#  'BA',
#  'SP',
#  'BA',
#  'AM',
#  'SE',
#  'BA',
#  'BA',
#  'GO',
#  'PE',
#  'CE',
#  'SP',
#  'CE',
#  'CE',
#  'PE',
#  'RN',
#  'AL',
#  'SP',
#  'CE',
#  'PB',
#  'SE',
#  'CE',
#  'CE',
#  'SP',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'SP',
#  'GO',
#  'PE',
#  'BA',
#  'GO',
#  'PE',
#  'GO',
#  'CE',
#  'CE',
#  'CE',
#  'AM',
#  'RS',
#  'BA',
#  'DF',
#  'PE',
#  'PE',
#  'SP',
#  'CE',
#  'CE',
#  'DF',
#  'BA',
#  'AM',
#  'MT',
#  'BA',
#  'PE',
#  'BA',
#  'PE',
#  'RN',
#  'PE',
#  'BA',
#  'MA',
#  'CE',
#  'BA',
#  'BA',
#  'DF',
#  'PB',
#  'GO',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'GO',
#  'CE',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'CE',
#  'BA',
#  'SP',
#  'PE',
#  'SP',
#  'SP',
#  'PB',
#  'BA',
#  'SP',
#  'MA',
#  'GO',
#  'SP',
#  'CE',
#  'BA',
#  'CE',
#  'RN',
#  'CE',
#  'BA',
#  'SP',
#  'PE',
#  'PE',
#  'CE',
#  'BA',
#  'SP',
#  'PB',
#  ...]

# %%
df['ESTADO']=estado_lista

# %%
df
# Out:
#              ID                                             TEMA  \
# 0     149490335                            TEMPO DE ATENDIMENTO
# 1     149499817                       Hapvida não tem nutrólogo
# 2     149498293             Descaso de tratamento de Hemodiálise
# 3     149495455  DESORGANIZAÇÃO E FALTA DE RESOLUÇÃO DE PROBLEMA
# 4     149495285                       Liberação de Procedimento
# ...         ...                                              ...
# 1011  150005391                                 Mal atendimento
# 1012  150004057                        Agenda médica nunca abre
# 1013  150000291                             Péssimo atendimento
# 1014  150019173                      Imagem dos exames realizado
# 1015  150001141                            Demora no atendimento
#
#                 LOCAL      TEMPO  \
# 0         Recife - PE 2022-01-09
# 1       Salvador - BA 2022-01-09
# 2         Olinda - PE 2022-01-09
# 3        Goiânia - GO 2022-01-09
# 4      Fortaleza - CE 2022-01-09
# ...               ...        ...
# 1011     Goiânia - GO 2022-12-09
# 1012   Fortaleza - CE 2022-12-09
# 1013    Igarassu - PE 2022-12-09
# 1014       Natal - RN 2022-12-09
# 1015  Camaragibe - PE 2022-12-09
#
#                                               CATEGORIA          STATUS  \
# 0     Demora na execução<->Plano<->Planos de Saúde<-...  Não respondida
# 1     Planos de saúde<->Qualidade do serviço prestad...  Não respondida
# 2     Demora para autorização de consultas, exames e...      Respondida
# 3     Demora na execução<->Planos de saúde<->Planos ...  Não respondida
# 4     Planos de saúde<->Planos de Saúde<->Hapvida Sa...      Respondida
# ...                                                 ...             ...
# 1011  Planos de saúde<->Planos de Saúde<->Mau atendi...  Não respondida
# 1012  Planos de saúde<->Planos de Saúde<->Hapvida Sa...       Resolvido
# 1013  Mau atendimento do prestador de serviço<->Não ...      Respondida
# 1014  Exames Lab e imagens<->Não encontrei meu probl...  Não respondida
# 1015  Exames Lab e imagens<->Horário de atendimento<...  Não respondida
#
#                                               DESCRICAO  \
# 0     Acabei de sair de uma urgência por causa de at...
# 1     O Hapvida diz que fornece o serviço de nutrólo...
# 2     Meu irmão Wagner Santiago, estava internado de...
# 3     Agendei pelo chat um procedimento onde fui bem...
# 4     Paguei fatura do plano em atraso e tal atraso ...
# ...                                                 ...
# 1011  Fui atendida hoje no dia 09/09/22, na clinica ...
# 1012  Por vários meses a agenda da Dr. (Editado pelo...
# 1013  Me encaixaram para um endocrinologista no dia ...
# 1014  O hapvida tem sido negligente com os pacientes...
# 1015  Fiz um agendamento de um exame de endoscopia p...
#
#                                                     URL   ANO  MES  DIA  \
# 0     https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 1     https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 2     https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 3     https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 4     https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# ...                                                 ...   ...  ...  ...
# 1011  https://www.reclameaqui.com.br//hapvida-saude/...  2022   12    9
# 1012  https://www.reclameaqui.com.br//hapvida-saude/...  2022   12    9
# 1013  https://www.reclameaqui.com.br//hapvida-saude/...  2022   12    9
# 1014  https://www.reclameaqui.com.br//hapvida-saude/...  2022   12    9
# 1015  https://www.reclameaqui.com.br//hapvida-saude/...  2022   12    9
#
#       DIA_DO_ANO  SEMANA_DO_ANO  DIA_DA_SEMANA  TRIMETRES  CASOS ESTADO
# 0              9              1              6          1     66     PE
# 1              9              1              6          1     66     BA
# 2              9              1              6          1     66     PE
# 3              9              1              6          1     66     GO
# 4              9              1              6          1     66     CE
# ...          ...            ...            ...        ...    ...    ...
# 1011         343             49              4          4     71     GO
# 1012         343             49              4          4     71     CE
# 1013         343             49              4          4     71     PE
# 1014         343             49              4          4     71     RN
# 1015         343             49              4          4     71     PE
#
# [1016 rows x 17 columns]

# %%
df[df['ESTADO']=='CE'].groupby('TEMPO').nunique()['ID'].plot(kind='bar')
# Out:
# <Axes: xlabel='TEMPO'>

# %%
def count_palavras(texto):
    return len(texto.split())

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\josia\appdata\local\programs\python\python312\lib\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\josia\appdata\local\programs\python\python312\lib\site-packages (from scipy) (1.26.4)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df['DESCRICAO'].apply(count_palavras).plot(kind='hist',density=True)
df['DESCRICAO'].apply(count_palavras).plot.kde()
# Out:
# <Axes: ylabel='Density'>
